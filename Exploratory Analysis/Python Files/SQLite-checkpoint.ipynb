# %%
# import dependencies
import sqlite3 as sql
import pandas as pd
import matplotlib.pyplot as plt

# %%
news = pd.read_csv('OnlineNewsPopularity.csv')
news.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# ...

# %%
# remove space before column names
news.columns = news.columns.str.replace(' ','')
news.head()
# Out:
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...      731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...      731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...      731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...      731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/      731.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  ...  \
# 0                  0.815385        4.0             2.0       1.0  ...
# ...

# %%
conn = sql.connect('news.db')
news.to_sql('news', conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/5f/4tn89f_91tb97kg7lybdjrlh0000gn/T/ipykernel_32761/450573838.py in <module>
#       1 conn = sql.connect('news.db')
# ----> 2 news.to_sql('news', conn)
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ...

# %%
conn = sql.connect('news.db')
news = pd.read_sql('SELECT * FROM news', conn)

# %%
url = pd.read_sql('SELECT url FROM news', conn)
url
# Out:
#                                                      url
# 0      http://mashable.com/2013/01/07/amazon-instant-...
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...
# 2      http://mashable.com/2013/01/07/apple-40-billio...
# 3      http://mashable.com/2013/01/07/astronaut-notre...
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/
# ...                                                  ...
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/
# 39643  http://mashable.com/2014/12/27/youtube-channel...
#
# [39644 rows x 1 columns]

# %%
shares = pd.read_sql('SELECT shares FROM news', conn)
shares
# Out:
#        shares
# 0         593
# 1         711
# 2        1500
# 3        1200
# 4         505
# ...       ...
# 39639    1800
# 39640    1900
# 39641    1900
# 39642    1100
# 39643    1300
#
# [39644 rows x 1 columns]
